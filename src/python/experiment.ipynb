# %%
import sys
sys.path.append('/home/wakana/kudoh-lab/cnn_cpp/src/protos')

# %%
import cnn_params_pb2

# %%
params = cnn_params_pb2.Params()

# %%
try:
  with open("/home/wakana/kudoh-lab/cnn_cpp/simple.pb", "rb") as f:
      params.ParseFromString(f.read())
except IOError:
  print ("Could not open file.  Creating a new one.")

# %%
import numpy as np

# %%
w1 = np.array(params.weights[0].w)
b1 = np.array(params.biases[0].b)
w2 = np.array(params.weights[1].w)
b2 = np.array(params.biases[1].b)
w3 = np.array(params.weights[2].w)
b3 = np.array(params.biases[2].b)

# %%
import matplotlib.pyplot as plt

# %%
_, (axL, axR) = plt.subplots(ncols=2, figsize=(10,4))
axL.hist(w1, bins=100)
axR.hist(b1, bins=30, color='green')
plt.show()

# %%
_, (axL, axR) = plt.subplots(ncols=2, figsize=(10,4))
axL.hist(w2, bins=12*12*30)
axR.hist(b2, bins=100, color='green')
plt.show()

# %%
_, (axL, axR) = plt.subplots(ncols=2, figsize=(10,4))
axL.hist(w3, bins=100)
axR.hist(b3, bins=10, color='green')
plt.show()
